# %% [raw]
# import pandas as pd
# pd.set_option('display.max_rows', 100)
# opiode_df = pd.read_csv('/Users/nickphom/docs/SacHacks Data/opiod_dataset.csv')

# %%
city_df = pd.read_csv('/Users/nickphom/docs/SacHacks Data/2014_us_cities.csv')

# %%
display(opiode_df)
# Out:
#       Unnamed: 0       nppes_provider_city  \
# 0           3929                   HOUSTON
# 1           4100              JACKSONVILLE
# 2           8349               SPRINGFIELD
# 3           7724               SAN ANTONIO
# 4           4619                 LAS VEGAS
# ...          ...                       ...
# 9880        9399                 WESMISTER
# 9881        4804              LITTLE FERRY
# 9882        6282           NORTH STRATFORD
# 9883        6263  NORTH PORT CARRIER ANNEX
# 9884        4878              LONS ANGELES
#
#       Total Amount of 30 day fills for opioids
# 0                                     486725.1
# 1                                     372875.2
# 2                                     370376.9
# 3                                     369776.3
# 4                                     363208.4
# ...                                        ...
# 9880                                      11.0
# 9881                                      11.0
# ...

# %%
opiode_df.rename(columns={'nppes_provider_city': 'name'}, inplace= True)

# %%
display(opiode_df)
# Out:
#       Unnamed: 0                      name  \
# 0           3929                   HOUSTON
# 1           4100              JACKSONVILLE
# 2           8349               SPRINGFIELD
# 3           7724               SAN ANTONIO
# 4           4619                 LAS VEGAS
# ...          ...                       ...
# 9880        9399                 WESMISTER
# 9881        4804              LITTLE FERRY
# 9882        6282           NORTH STRATFORD
# 9883        6263  NORTH PORT CARRIER ANNEX
# 9884        4878              LONS ANGELES
#
#       Total Amount of 30 day fills for opioids
# 0                                     486725.1
# 1                                     372875.2
# 2                                     370376.9
# 3                                     369776.3
# 4                                     363208.4
# ...                                        ...
# 9880                                      11.0
# 9881                                      11.0
# ...

# %%
display(city_df)
# Out:
#                    name      pop        lat         lon
# 0             NEW YORK   8287238  40.730599  -73.986581
# 1          LOS ANGELES   3826423  34.053717 -118.242727
# 2              CHICAGO   2705627  41.875555  -87.624421
# 3              HOUSTON   2129784  29.758938  -95.367697
# 4         PHILADELPHIA   1539313  39.952335  -75.163789
# ...                 ...      ...        ...         ...
# 3223      SPANISH FORT      7102  30.674913  -87.915272
# 3224        PLAQUEMINE      7102  30.289083  -91.234274
# 3225  MILTON-FREEWATER      7102  45.932635 -118.387743
# 3226            BENTON      7096  36.034529  -88.101285
# 3227        OCEAN CITY      7094  39.277616  -74.574600
#
# [3228 rows x 4 columns]

# %%
city_df['name'] = map(lambda x: str(x).upper(),inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-ffd72359f3af> in <module>
# ----> 1 city_df['name'] = map(lambda x: str(x).upper(),inplace=True)
#
# TypeError: map() takes no keyword arguments

# %%
city_df['name'] = city_df['name'].apply(lambda x: x.upper())

# %%
city_df.rename(columns={'nppes_provider_city': 'name'}, inplace= True)

# %%
city_df = city_df.drop(['pop'], axis= 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-a882c8705860> in <module>
# ----> 1 city_df = city_df.drop(['pop'], axis= 1)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
display(city_df)
# Out:
#                   name        lat         lon
# 0             NEW YORK  40.730599  -73.986581
# 1          LOS ANGELES  34.053717 -118.242727
# 2              CHICAGO  41.875555  -87.624421
# 3              HOUSTON  29.758938  -95.367697
# 4         PHILADELPHIA  39.952335  -75.163789
# ...                ...        ...         ...
# 3223      SPANISH FORT  30.674913  -87.915272
# 3224        PLAQUEMINE  30.289083  -91.234274
# 3225  MILTON-FREEWATER  45.932635 -118.387743
# 3226            BENTON  36.034529  -88.101285
# 3227        OCEAN CITY  39.277616  -74.574600
#
# [3228 rows x 3 columns]

# %%
city_df['name'] = city_df['name'].str.strip()
opiode_df['name'] = opiode_df['name'].str.strip()

# %%
result = city_df[['name', 'lat', 'lon']].merge(opiode_df[['name','Total Amount of 30 day fills for opioids']], on = 'name', how = 'left')

# %%
result.dropna(subset=['Total Amount of 30 day fills for opioids'], inplace= True)

# %%
display(result)
# Out:
#               name        lat         lon  \
# 0         NEW YORK  40.730599  -73.986581
# 1      LOS ANGELES  34.053717 -118.242727
# 2          CHICAGO  41.875555  -87.624421
# 3          HOUSTON  29.758938  -95.367697
# 4     PHILADELPHIA  39.952335  -75.163789
# ...            ...        ...         ...
# 3222      SULLIVAN  36.496667  -82.286903
# 3223  SPANISH FORT  30.674913  -87.915272
# 3224    PLAQUEMINE  30.289083  -91.234274
# 3226        BENTON  36.034529  -88.101285
# 3227    OCEAN CITY  39.277616  -74.574600
#
#       Total Amount of 30 day fills for opioids
# 0                                     224141.0
# 1                                     278805.2
# 2                                     300934.0
# 3                                     486725.1
# 4                                     342793.4
# ...                                        ...
# 3222                                   25998.4
# 3223                                    2110.1
# ...

# %%
opiode_df['name'].isin(cit['name']).value_counts()
# Out:
# False    7491
# True     2394
# Name: name, dtype: int64

# %%
result.to_csv('/Users/nickphom/docs/SacHacks Data/mapdata.csv')
